# %% [markdown]
# # Grafeno bicapa rotado
#
# A continuación se mostrará el procedimiento para obtener la PC para una bicapas de grafeno con distintas rotaciones.
#
# Las rotaciones relativas entre las capas de grafeno que conformarán cada sistema serán en ángulos no-conmensurables. Estos ángulos serán los siguientes:
#
# -  $2.54^\circ$
# -  $5.63^\circ$
# - $14.21^\circ$
# - $16.18^\circ$
# - $23.85^\circ$
#
# *La explicación paso a paso del calculo está descrito en el archivo "01_Ejemplo_Completo"

# %% [markdown]
# ### Carga de System y creación de grafenos
#
# La carga de las funciones requeridas se efectúa al importar nookiin y de este todas las funciones de nookiin.system, para esto es necesario ya haber instalado nookiin mediante el comando `pip install .` desde consola.

# %%
import sys
import os

import nookiin
from nookiin.system import *
# Out:
# Load System
# Nookiin Ready-to-work

# %%
c1 = graphene()
c2 = graphene()
c1.showPC()
c2.showPC()

# %% [markdown]
# ### tBLG con 2.54$^\circ$

# %%
t = 2.54
tBLG = System([c1,c2.mRot(t)])
tBLG_op = tBLG.generateSuperCell(RoS=20,eps=0.01,showTable=True)
tBLG_op.exportPC(PCname=f"tBLG({t})")
tBLG_op.diffractionPattern(border=1)
# Out:
# Size of the primitive vectors: |a|=50.71445Å, |b|=50.71445Å
# Angle between vectors: 120.000°
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |         Lattice         |       T       |      Deformation      |    Distortion:δ//θ    | #Atoms |
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |                         |  |  12   12|  |  | 1.00000  0.00000|  |    +0.0% // +0.0°     |  864   |
# |        Graphene         |  | -12   24|  |  | 0.00000  1.00000|  |    +0.0% // +0.0°     |        |
# |                         |               |                       |                       |        |
# |                         |  |  11   13|  |  | 1.00100 -0.00432|  |   -0.116% // +0.21°   |  866   |
# |     Graphene(2.54°)     |  | -13   24|  |  | 0.00432  0.99668|  |   -0.116% // +0.21°   |        |
# ...

# %% [markdown]
# ### tBLG 5.63$^\circ$

# %%
t = 5.63
tBLG = System([c1,c2.mRot(t)])
tBLG_op = tBLG.generateSuperCell(RoS=20,eps=0.01,showTable=True)
tBLG_op.exportPC(PCname=f"tBLG({t})")
tBLG_op.diffractionPattern(border=1)
# Out:
# Size of the primitive vectors: |a|=42.75225Å, |b|=42.75225Å
# Angle between vectors: 120.000°
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |         Lattice         |       T       |      Deformation      |    Distortion:δ//θ    | #Atoms |
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |                         |  |  18   -1|  |  | 1.00000  0.00000|  |    +0.0% // +0.0°     |  614   |
# |        Graphene         |  |   1   17|  |  | 0.00000  1.00000|  |    +0.0% // +0.0°     |        |
# |                         |               |                       |                       |        |
# |                         |  |  17    1|  |  | 1.00036 -0.00073|  |    +0.0% // +0.04°    |  614   |
# |     Graphene(5.63°)     |  |  -1   18|  |  | 0.00073  0.99964|  |    +0.0% // +0.04°    |        |
# ...

# %% [markdown]
# ### tBLG 14.21$^\circ$

# %%
t = 14.21
tBLG = System([c1,c2.mRot(t)])
tBLG_op = tBLG.generateSuperCell(RoS=20,eps=0.01,showTable=True)
tBLG_op.exportPC(PCname=f"tBLG({t})")
tBLG_op.diffractionPattern(border=1)
# Out:
# Size of the primitive vectors: |a|=34.42044Å, |b|=34.42044Å
# Angle between vectors: 120.000°
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |         Lattice         |       T       |      Deformation      |    Distortion:δ//θ    | #Atoms |
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |                         |  |  13  -15|  |  | 1.00000  0.00000|  |    +0.0% // +0.0°     |  398   |
# |        Graphene         |  |  15   -2|  |  | 0.00000  1.00000|  |    +0.0% // +0.0°     |        |
# |                         |               |                       |                       |        |
# |                         |  |  15  -13|  |  | 0.99894  0.00211|  |    +0.0% // -0.1°     |  398   |
# |    Graphene(14.21°)     |  |  13    2|  |  |-0.00211  1.00105|  |    +0.0% // -0.1°     |        |
# ...

# %% [markdown]
# ### tBLG 16.18$^\circ$

# %%
t = 16.18
tBLG = System([c1,c2.mRot(t)])
tBLG_op = tBLG.generateSuperCell(RoS=20,eps=0.005,showTable=True)
tBLG_op.exportPC(PCname=f"tBLG({t})")
tBLG_op.diffractionPattern(border=1)
# Out:
# Size of the primitive vectors: |a|=45.58296Å, |b|=45.58296Å
# Angle between vectors: 120.000°
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |         Lattice         |       T       |      Deformation      |    Distortion:δ//θ    | #Atoms |
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |                         |  |   3   17|  |  | 1.00000  0.00000|  |    +0.0% // +0.0°     |  698   |
# |        Graphene         |  | -17   20|  |  | 0.00000  1.00000|  |    +0.0% // +0.0°     |        |
# |                         |               |                       |                       |        |
# |                         |  |  -3   20|  |  | 0.99806  0.00386|  |    +0.0% // -0.19°    |  698   |
# |    Graphene(16.18°)     |  | -20   17|  |  |-0.00386  1.00193|  |    +0.0% // -0.19°    |        |
# ...

# %% [markdown]
# ### tBLG 23.85$^\circ$

# %%
t = 23.85
tBLG = System([c1,c2.mRot(t)])
tBLG_op = tBLG.generateSuperCell(RoS=20,eps=0.01,showTable=True)
tBLG_op.exportPC(PCname=f"tBLG({t})")
tBLG_op.diffractionPattern(border=1)
# Out:
# Size of the primitive vectors: |a|=41.04715Å, |b|=41.04715Å
# Angle between vectors: 120.000°
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |         Lattice         |       T       |      Deformation      |    Distortion:δ//θ    | #Atoms |
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |                         |  |   6  -19|  |  | 1.00000  0.00000|  |    +0.0% // +0.0°     |  566   |
# |        Graphene         |  |  19  -13|  |  | 0.00000  1.00000|  |    +0.0% // +0.0°     |        |
# |                         |               |                       |                       |        |
# |                         |  |  13  -19|  |  | 1.00167 -0.00336|  |    +0.0% // +0.17°    |  566   |
# |    Graphene(23.85°)     |  |  19   -6|  |  | 0.00336  0.99832|  |    +0.0% // +0.17°    |        |
# ...
