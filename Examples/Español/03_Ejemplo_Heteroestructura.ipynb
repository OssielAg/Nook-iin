# %% [markdown]
# # Heteroestructura multicapa
#
# A continuación se mostrará el procedimiento para obtener la PC para una heteroestructura con multiples capas, los sistemas aquí evaluados son puramente teoricos, sin ningún proposito más que mostrar la funcionalidad de Nook'iin.
#
# En cada ejemplo se creará el sistema, se calculará su Celda primitiva con una deformación menor a un ''$\varepsilon$'' en cada capa, se mostrará en pantalla la tabla correspondiente y su representación en el espacio real, se exportará el resultado en un archivo POSCAR y finalmente se mostrará su patrón de difracción.
#
# Los materiales a usar serán:
#
# -  $\beta$-GeSe
# -  CdS
# -  hBN
# -  WS2
# -  WSe2
# -  Fosforeno Negro
#
# *Los ángulos de rotación de cada capa se indicarán en cada ejemplo

# %% [markdown]
# ### Carga de System y creación de Redes
#
# La carga de las funciones requeridas se efectúa al importar nookiin y de este todas las funciones de nookiin.system, para esto es necesario ya haber instalado nookiin mediante el comando `pip install .` desde consola.

# %%
import sys
import os
import nookiin
from nookiin.system import *
# Out:
# Load System
# Nookiin Ready-to-work

# %%
VASP_Files = os.path.abspath(os.path.join(os.getcwd(), '..', '..', 'VASP_Files'))
bGeSe = importLattice(VASP_Files+"/GeSe_Beta")
CdS = importLattice(VASP_Files+"/CdS")
hBN = importLattice(VASP_Files+"/hBN")
WS2 = importLattice(VASP_Files+"/WS2")
WSe2 = importLattice(VASP_Files+"/WSe2")
bP = importLattice(VASP_Files+"/Ph")
# Out:
# File 'C:\SS\Nook’iin\Nook-iin\VASP_Files/GeSe_Beta.vasp' will be read
# --Lattice created successfully
# File 'C:\SS\Nook’iin\Nook-iin\VASP_Files/CdS.vasp' will be read
# --Lattice created successfully
# File 'C:\SS\Nook’iin\Nook-iin\VASP_Files/hBN.vasp' will be read
# --Lattice created successfully
# File 'C:\SS\Nook’iin\Nook-iin\VASP_Files/WS2.vasp' will be read
# --Lattice created successfully
# File 'C:\SS\Nook’iin\Nook-iin\VASP_Files/WSe2.vasp' will be read
# --Lattice created successfully
# File 'C:\SS\Nook’iin\Nook-iin\VASP_Files/Ph.vasp' will be read
# --Lattice created successfully

# %% [markdown]
# ### Sistema: Fosforeno Negro-hBN$(3.25^\circ)$-CdS$(8.76^\circ)$-hBN$(12.62^\circ)$

# %%
S1 = System([bP,hBN.mRot(3.25),CdS.mRot(8.76),hBN.mRot(12.62)])
S1_op = S1.generateSuperCell(RoS=20,eps=0.01,prntRes=False,showTable=True)
S1_op.primitive_lattice.showme(t=1)
S1_op.exportPC(PCname='ejemplo3_S1')
S1_op.diffractionPattern(border=1)
# Out:
# Size of the primitive vectors: |a|=67.21108Å, |b|=81.44788Å
# Angle between vectors: 109.551°
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |         Lattice         |       T       |      Deformation      |    Distortion:δ//θ    | #Atoms |
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |                         |  |  13   13|  |  | 1.00000  0.00000|  |    +0.0% // +0.0°     |  1456  |
# |       Phosphorene       |  | -12   16|  |  | 0.00000  1.00000|  |    +0.0% // +0.0°     |        |
# |                         |               |                       |                       |        |
# |                         |  |  28    3|  |  | 1.01042 -0.00041|  |   +0.725% // -0.31°   |  1886  |
# |       hBN(3.25°)        |  | -25   31|  |  |-0.00638  0.99864|  |   -0.157% // +0.02°   |        |
# ...

# %% [markdown]
# ### Sistema WS2-WSe2$(1.25^\circ)$-CdS$(-3.48^\circ)$-Fosforeno Negro$(15.83^\circ)$-$\beta$_GeSe$(8.67^\circ)$

# %%
S2 = System([WS2,WSe2.mRot(1.25),CdS.mRot(-3.48),bP.mRot(15.83),bGeSe.mRot(8.67)])
S2_op = S2.generateSuperCell(RoS=25,eps=0.02,prntRes=False,showTable=True)
S2_op.primitive_lattice.showme(t=1)
S2_op.exportPC(PCname='ejemplo3_S2')
S2_op.diffractionPattern(border=1)
# Out:
# Size of the primitive vectors: |a|=54.85404Å, |b|=71.19170Å
# Angle between vectors: 28.900°
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |         Lattice         |       T       |      Deformation      |    Distortion:δ//θ    | #Atoms |
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |                         |  |  20   22|  |  | 1.00000  0.00000|  |    +0.0% // +0.0°     |  654   |
# |           WS2           |  |  11   23|  |  | 0.00000  1.00000|  |    +0.0% // +0.0°     |        |
# |                         |               |                       |                       |        |
# |                         |  |  19   21|  |  | 0.97426  0.01585|  |   -1.565% // -1.0°    |  567   |
# |       WSe2(1.25°)       |  |  10   21|  |  |-0.01987  1.02921|  |   +2.138% // -0.77°   |        |
# ...

# %% [markdown]
# ### Sistema $\beta$_GeSe-WS2$(12.53^\circ)$-hBN$(5.28^\circ)$-CdS$(11.68^\circ)$

# %%
S3 = System([bGeSe,WS2.mRot(12.53),hBN.mRot(5.28),CdS.mRot(11.68)])
S3_op = S3.generateSuperCell(RoS=20,eps=0.01,prntRes=False,showTable=True)
S3_op.primitive_lattice.showme(t=1)
S3_op.exportPC(PCname='ejemplo3_S3')
S3_op.diffractionPattern(border=1)
# Out:
# Size of the primitive vectors: |a|=92.94240Å, |b|=54.64507Å
# Angle between vectors: 129.629°
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |         Lattice         |       T       |      Deformation      |    Distortion:δ//θ    | #Atoms |
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |                         |  |   0   11|  |  | 1.00000  0.00000|  |    +0.0% // +0.0°     |  704   |
# |        GeSe_Beta        |  | -16    6|  |  | 0.00000  1.00000|  |    +0.0% // +0.0°     |        |
# |                         |               |                       |                       |        |
# |                         |  | -23   20|  |  | 0.99610  0.00106|  |   -0.587% // +0.2°    |  1359  |
# |       WS2(12.53°)       |  | -33    9|  |  | 0.00394  1.00135|  |   +0.082% // -0.05°   |        |
# ...

# %% [markdown]
# ### Sistema CdS-bGeSe$(3.25^\circ)$-hBN$(6.74^\circ)$-WS2$(11.42^\circ)$-WSe2$(9.74^\circ)$-FosforenoNegro$(-3.25^\circ)$-CdS$(-8.1^\circ)$-bGeSe$(13.69^\circ)$-hBN$(1.24^\circ)$-WS2$(-5.74^\circ)$-WSe2$(3.68^\circ)$-FosforenoNegro

# %%
S4 = System([CdS,
             bGeSe.mRot(3.25),
             hBN.mRot(6.74),
             WS2.mRot(13.34),
             WSe2.mRot(9.74),
             bP.mRot(-4.37),
             CdS.mRot(-8.1),
             bGeSe.mRot(13.42),
             hBN.mRot(1.24),
             WS2.mRot(-5.74),
             WSe2.mRot(3.68),
             bP])
S4_op = S4.generateSuperCell(RoS=20,eps=0.02,prntRes=False,showTable=True)
S4_op.primitive_lattice.showme(t=0.1)
S4_op.exportPC(PCname='ejemplo3_S4')
S4_op.diffractionPattern(border=1)
# Out:
# Size of the primitive vectors: |a|=85.45367Å, |b|=101.12767Å
# Angle between vectors: 33.410°
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |         Lattice         |       T       |      Deformation      |    Distortion:δ//θ    | #Atoms |
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |                         |  |   4   19|  |  | 1.00000  0.00000|  |    +0.0% // +0.0°     |  1240  |
# |           CdS           |  | -18   -8|  |  | 0.00000  1.00000|  |    +0.0% // +0.0°     |        |
# |                         |               |                       |                       |        |
# |                         |  |  13   25|  |  | 0.98272 -0.04446|  |   -1.727% // -0.25°   |  888   |
# |    GeSe_Beta(3.25°)     |  | -12   -6|  |  |-0.00277  0.98147|  |   -1.809% // +1.71°   |        |
# ...
