# %%
import nookiin
from nookiin.system import *
# Out:
# Load System
# Nookiin Ready-to-work

# %%
g1=graphene().mRot(13.5)
g2=grapheneC3().mRot(2.57)
g1.showme(), g2.showme()
# Out:
# (None, None)

# %%
hBn=importLattice("VASP_files/hBn")
hBn.showme()
# Out:
# File 'VASP_files/hBn.vasp' will be read
# --Lattice created successfully from file 'VASP_files/hBn.vasp'--

# %%
s1=System([hBn,g1,g2])

# %%
m=s1.ejecuta()

# %%
s1.createSuperLattice(m)
# Out:
# 1

# %%
s1.show()
# Out:
# TM:
# 	4	2
# 	-13	10
#
# System [hBN,Graphene(13.50°),Graphene(s3)(2.57°)]
# Unit cell with 412 atoms:
# Reciprocal Space:

# %%
s1.describeTM(m)
# Out:
# Size of the primitive vectors: |a|=28.85450Å, |b|=27.86114Å
# Angle between vectors: 153.572°
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |         Lattice         |       T       |      Deformation      |    Distortion:δ//θ    | #Atoms |
# +-------------------------+---------------+-----------------------+-----------------------+--------+
# |                         |  |   4    2|  |  | 1.00000  0.00000|  |    +0.0% // +0.0°     |  132   |
# |           hBN           |  | -13   10|  |  | 0.00000  1.00000|  |    +0.0% // +0.0°     |        |
# |                         |               |                       |                       |        |
# |                         |  | -11   13|  |  | 0.97443  0.05037|  |   -1.255% // -1.28°   |  136   |
# |    Graphene(13.50°)     |  | -12    8|  |  |-0.02554  1.04600|  |   +2.174% // -2.45°   |        |
# ...
